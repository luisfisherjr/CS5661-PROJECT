# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train_data = pd.read_csv('../dataset/train.csv')

print(train_data.columns)
# Out:
# Index(['Id', 'Elevation', 'Aspect', 'Slope',
#        'Horizontal_Distance_To_Hydrology', 'Vertical_Distance_To_Hydrology',
#        'Horizontal_Distance_To_Roadways', 'Hillshade_9am', 'Hillshade_Noon',
#        'Hillshade_3pm', 'Horizontal_Distance_To_Fire_Points',
#        'Wilderness_Area1', 'Wilderness_Area2', 'Wilderness_Area3',
#        'Wilderness_Area4', 'Soil_Type1', 'Soil_Type2', 'Soil_Type3',
#        'Soil_Type4', 'Soil_Type5', 'Soil_Type6', 'Soil_Type7', 'Soil_Type8',
#        'Soil_Type9', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12',
#        'Soil_Type13', 'Soil_Type14', 'Soil_Type15', 'Soil_Type16',
#        'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type20',
#        'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24',
#        'Soil_Type25', 'Soil_Type26', 'Soil_Type27', 'Soil_Type28',
#        'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32',
#        'Soil_Type33', 'Soil_Type34', 'Soil_Type35', 'Soil_Type36',
# ...

# %%
features = ['Id', 'Elevation', 'Aspect', 'Slope',
       'Horizontal_Distance_To_Hydrology', 'Vertical_Distance_To_Hydrology',
       'Horizontal_Distance_To_Roadways', 'Hillshade_9am', 'Hillshade_Noon',
       'Hillshade_3pm', 'Horizontal_Distance_To_Fire_Points',
       'Wilderness_Area1', 'Wilderness_Area2', 'Wilderness_Area3',
       'Wilderness_Area4', 'Soil_Type1', 'Soil_Type2', 'Soil_Type3',
       'Soil_Type4', 'Soil_Type5', 'Soil_Type6', 'Soil_Type7', 'Soil_Type8',
       'Soil_Type9', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12',
       'Soil_Type13', 'Soil_Type14', 'Soil_Type15', 'Soil_Type16',
       'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type20',
       'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24',
       'Soil_Type25', 'Soil_Type26', 'Soil_Type27', 'Soil_Type28',
       'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32',
       'Soil_Type33', 'Soil_Type34', 'Soil_Type35', 'Soil_Type36',
       'Soil_Type37', 'Soil_Type38', 'Soil_Type39', 'Soil_Type40']


X = train_data[features]
y = train_data['Cover_Type']

# Scale my training set 
train_data_normalized = preprocessing.scale(X)

# create a training DataFrame
train_data_df = pd.DataFrame(train_data_normalized)

train_data_df[:10]
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.731936 -0.367095 -0.959980 -1.597132  0.146639 -0.834074 -0.908681
# 1 -1.731707 -0.381461 -0.914559 -1.715424 -0.072337 -0.932054 -0.999246
# 2 -1.731478  0.130912 -0.160577 -0.887379  0.194243  0.227369  1.106379
# 3 -1.731249  0.085421 -0.015231  0.177250  0.070474  1.092853  1.038455
# 4 -1.731020 -0.369489 -1.014485 -1.715424 -0.353198 -0.850404 -0.998491
# 5 -1.730791 -0.407798 -0.224166 -1.242255  0.346574 -1.079023 -1.243015
# 6 -1.730562 -0.343152 -1.014485 -1.123963  0.203764 -0.752425 -0.815853
# 7 -1.730333 -0.345547 -0.978148 -1.478839  0.032391 -0.719765 -0.861135
# 8 -1.730103 -0.316816 -1.014485 -0.887379  0.060953  0.080400 -0.790947
# 9 -1.729874 -0.328787 -0.887307 -0.769087  0.094276 -0.654445 -0.813589
#
#          7         8         9     ...           45        46        47  \
# 0  0.271454  0.571653  0.281259    ...    -0.149835 -0.218671 -0.206085
# ...

# %%
# Initializing one ANN.
my_ANN = MLPClassifier(hidden_layer_sizes=(80,), activation= 'logistic', 
                       solver='adam', alpha=1e-5, random_state=1, 
                       learning_rate_init = 0.002)

# train my model on training set
my_ANN.fit(train_data_df, y)
# Out:
# /Users/naifsaid/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='logistic', alpha=1e-05, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(80,), learning_rate='constant',
#        learning_rate_init=0.002, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
# Weights:
print(my_ANN.coefs_)
# The ith element in the list represents the weight matrix corresponding to layer i.

print('\n')

# Bias weights:
print(my_ANN.intercepts_)
# The ith element in the list represents the bias vector corresponding to layer i + 1.
# Out:
# [array([[ 0.46477615, -0.30159686, -0.24640731, ...,  0.66119566,
#         -0.20158023,  0.0249228 ],
#        [ 4.28534604,  1.82855702,  2.2296437 , ...,  1.74021881,
#         -2.36651082, -3.30386657],
#        [ 0.26775807, -0.05979638,  0.02286335, ...,  0.91320304,
#         -0.02881785, -0.17893344],
#        ...,
#        [ 0.16638788,  1.13289466,  1.69096196, ..., -0.91090246,
#          1.44175698,  1.04833673],
#        [ 0.43742827, -0.20451617,  0.23337563, ...,  0.41723809,
#         -1.02476396, -0.26839928],
#        [ 0.28737803,  0.45457372, -0.22020735, ...,  0.33958681,
#         -1.0916471 , -0.06752598]]), array([[ 7.27811856e-01,  1.43823034e-01,  1.86360259e-01,
#         -3.65653355e+00, -1.62209576e-01, -2.93475040e+00,
#          7.74470456e-01],
#        [-4.94330216e-02, -4.42956907e-01,  9.24006023e-01,
#          7.95964778e-01, -1.49349695e+00, -1.01672210e+00,
#          1.09958175e+00],
#        [-4.21142295e-01,  7.85664897e-01,  1.25700865e+00,
# ...

# %%
# import testing data set
test_data = pd.read_csv('../dataset/test.csv')

# apply Normalization on it
test_data_binary = preprocessing.scale(X)

# create testing DataFrame
test_data_df = pd.DataFrame(data_binary)

test_data_df[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-97877553f412> in <module>()
#       6
#       7 # create testing DataFrame
# ----> 8 test_data_df = pd.DataFrame(data_binary)
#       9
#      10 test_data_df[:10]
#
# NameError: name 'data_binary' is not defined

# %%
# Testing on the testing set:
y_predict_ann = my_ANN.predict(test_data_df)

print(y_predict_ann)

# %% [markdown]
# ### Try applying MLPClassifier of (training set) to see how it perform

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data_df, y,test_size=0.2, random_state=2)

print(X_train.shape)
print(y_train.shape)

# Initializing one ANN.
my_ANN = MLPClassifier(hidden_layer_sizes=(80,), activation= 'logistic', 
                       solver='adam', alpha=1e-5, random_state=1, 
                       learning_rate_init = 0.002)

# train my model on training set
my_ANN.fit(X_train, y_train)

# Testing on the testing set:
y_predict_ann = my_ANN.predict(X_test)
print(y_predict_ann)


# Calculate the accuracy
score_ann = accuracy_score(y_test, y_predict_ann)
print("Accuracy: ",score_ann)

# %%
randomForest_obj = RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=3)
my_AdaBoost_obj = AdaBoostClassifier(randomForest_obj, n_estimators = 30, learning_rate=0.2,random_state=3)
my_AdaBoost_obj.fit(X_train, y_train)
X_predict= my_AdaBoost_obj.predict(X_test)

score = accuracy_score(y_test, X_predict)
print("Adaboost Score: ", score)

# %%
decisionTreeClassifierObj = DecisionTreeClassifier(random_state=2)
my_AdaBoost_obj = AdaBoostClassifier(decisionTreeClassifierObj, n_estimators = 50, learning_rate=0.7, random_state=2)
my_AdaBoost_obj.fit(X_train, y_train)
X_predict= my_AdaBoost_obj.predict(X_test)

score = accuracy_score(y_test, X_predict)
print("Adaboost Score: ", score)
